# %%
import yfinance as yf
#from curl_cffi import requests
import matplotlib.pyplot as plt
from scipy.signal import find_peaks
import numpy as np
from datetime import date, timedelta, datetime

startDate = '1900-01-01'
endDate = (datetime.now() - timedelta(1)).strftime('%Y-%m-%d')

# Step 1: Create a curl_cffi session to bypass rate limits
#session = requests.Session(impersonate="chrome")

# Step 2: Use the session in yfinance

symbol = "AAPL"
ticker = yf.Ticker(symbol)

# Safe fallback (DON’T use .info directly)
try:
    companyName = ticker.fast_info.get("lastPrice", symbol)
except:
    companyName = symbol

#symbol = "AAPL"
#ticker = yf.Ticker(symbol, session=session)
companyName = ticker.info.get('shortName', 'N/A')
data_df = ticker.history(start=startDate, end=endDate, interval="1mo")

# Step 3: Clean and extract prices
close_prices = data_df['Close'].dropna().values
dates = data_df.index[:len(close_prices)]

# Step 4: Detect peaks and troughs
peaks, _ = find_peaks(close_prices, distance=10, prominence=10)
troughs, _ = find_peaks(-close_prices, distance=10, prominence=10)

# Combine and limit to 9 wave points
wave_points = sorted(list(peaks) + list(troughs))
wave_points = wave_points[:min(9, len(wave_points))]
wave_labels = ['0', '1', '2', '3', '4', '5', 'A', 'B', 'C']

# Step 5: Plot
plt.figure(figsize=(14, 7))
plt.plot(dates, close_prices, label="Close", color='gray')

for i, idx in enumerate(wave_points):
    plt.plot(dates[idx], close_prices[idx], 'ro')
    plt.text(dates[idx], close_prices[idx] * 1.01, wave_labels[i], color='red', fontsize=12, ha='center')

plt.title(companyName + " Elliott Wave Approximation")
plt.xlabel("Date")
plt.ylabel("Price")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# $AAPL: possibly delisted; no price data found  (period=1y)
# $AAPL: possibly delisted; no price data found  (period=5d)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 28
#      24     companyName = symbol
#      26 #symbol = "AAPL"
#      27 #ticker = yf.Ticker(symbol, session=session)
# ---> 28 companyName = ticker.info.get('shortName', 'N/A')
#      29 data_df = ticker.history(start=startDate, end=endDate, interval="1mo")
#      31 # Step 3: Clean and extract prices
#
# File ~/miniconda3/lib/python3.12/site-packages/yfinance/ticker.py:159, in Ticker.info(self)
#     157 @property
#     158 def info(self) -> dict:
# --> 159     return self.get_info()
#
# File ~/miniconda3/lib/python3.12/site-packages/yfinance/base.py:244, in TickerBase.get_info(self, proxy)
#     242 def get_info(self, proxy=None) -> dict:
# ...

# %%
last_idx = wave_points[-1]

if close_prices[last_idx] > close_prices[wave_points[-2]]:
    signal = "Bullish"
else:
    signal = "Bearish"

print("Current Signal:", signal)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 last_idx = wave_points[-1]
#       3 if close_prices[last_idx] > close_prices[wave_points[-2]]:
#       4     signal = "Bullish"
#
# NameError: name 'wave_points' is not defined
