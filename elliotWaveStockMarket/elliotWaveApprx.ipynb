# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.signal import find_peaks
import numpy as np
from alpha_vantage.timeseries import TimeSeries

# -----------------------------
# Step 1: Setup API
# -----------------------------
API_KEY = "HVP1631QQ0BGFXE2"   # 🔥 replace this

symbol = "AAPL"

ts = TimeSeries(key=API_KEY, output_format='pandas')

# -----------------------------
# Step 2: Get data
# -----------------------------
data, meta = ts.get_daily(symbol=symbol, outputsize='full')

# Clean columns
data.columns = ['open', 'high', 'low', 'close', 'volume']

# Sort oldest → newest
data = data.sort_index()

# -----------------------------
# Step 3: Extract prices
# -----------------------------
close_prices = data['close'].values
dates = data.index

# -----------------------------
# Step 4: Detect peaks/troughs
# -----------------------------
peaks, _ = find_peaks(close_prices, distance=20, prominence=10)
troughs, _ = find_peaks(-close_prices, distance=20, prominence=10)

wave_points = sorted(list(peaks) + list(troughs))[:9]
wave_labels = ['0', '1', '2', '3', '4', '5', 'A', 'B', 'C']

# -----------------------------
# Step 5: Signal detection (MODEL OUTPUT 🔥)
# -----------------------------
if len(wave_points) >= 2:
    last = wave_points[-1]
    prev = wave_points[-2]
    signal = "Bullish" if close_prices[last] > close_prices[prev] else "Bearish"
else:
    signal = "Neutral"

print(f"Current Signal: {signal}")

# -----------------------------
# Step 6: Plot
# -----------------------------
plt.figure(figsize=(14, 7))
plt.plot(dates, close_prices, color='gray')

for i, idx in enumerate(wave_points):
    plt.plot(dates[idx], close_prices[idx], 'ro')
    plt.text(dates[idx], close_prices[idx]*1.01, wave_labels[i], ha='center')

plt.title(f"{symbol} Elliott Wave Approximation ({signal})")
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 18
#      13 ts = TimeSeries(key=API_KEY, output_format='pandas')
#      15 # -----------------------------
#      16 # Step 2: Get data
#      17 # -----------------------------
# ---> 18 data, meta = ts.get_daily(symbol=symbol, outputsize='full')
#      20 # Clean columns
#      21 data.columns = ['open', 'high', 'low', 'close', 'volume']
#
# File ~/miniconda3/lib/python3.12/site-packages/alpha_vantage/alphavantage.py:218, in AlphaVantage._output_format.<locals>._format_wrapper(self, *args, **kwargs)
#     216 @wraps(func)
#     217 def _format_wrapper(self, *args, **kwargs):
# --> 218     call_response, data_key, meta_data_key = func(
#     219         self, *args, **kwargs)
#     220     if 'json' in self.output_format.lower() or 'pandas' \
#     221             in self.output_format.lower():
#     222         if data_key is not None:
#
# File ~/miniconda3/lib/python3.12/site-packages/alpha_vantage/alphavantage.py:160, in AlphaVantage._call_api_on_func.<locals>._call_wrapper(self, *args, **kwargs)
#     158 else:
#     159     url = '{}{}'.format(url, apikey_parameter)
# --> 160 return self._handle_api_call(url), data_key, meta_data_key
#
# File ~/miniconda3/lib/python3.12/site-packages/alpha_vantage/alphavantage.py:361, in AlphaVantage._handle_api_call(self, url)
#     359     raise ValueError(json_response["Error Message"])
#     360 elif "Information" in json_response and self.treat_info_as_error:
# --> 361     raise ValueError(json_response["Information"])
#     362 elif "Note" in json_response and self.treat_info_as_error:
#     363     raise ValueError(json_response["Note"])
#
# ValueError: Thank you for using Alpha Vantage! The outputsize=full parameter value is a premium feature for the TIME_SERIES_DAILY endpoint. You may subscribe to any of the premium plans at https://www.alphavantage.co/premium/ to instantly unlock all premium features

# %%
last_idx = wave_points[-1]

if close_prices[last_idx] > close_prices[wave_points[-2]]:
    signal = "Bullish"
else:
    signal = "Bearish"

print("Current Signal:", signal)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 last_idx = wave_points[-1]
#       3 if close_prices[last_idx] > close_prices[wave_points[-2]]:
#       4     signal = "Bullish"
#
# NameError: name 'wave_points' is not defined

# %%
import yfinance as yf
df = yf.download("AAPL", period="1y")
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAPL']: AttributeError("'str' object has no attribute 'name'")
